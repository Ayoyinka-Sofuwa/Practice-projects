# %%
import pandas as pd

# %%
#loading the data into the pandas dataframe
df = pd.read_csv("ANZ.csv")
df.head() #displaying the first few rows of our data
# Out:
#        status  card_present_flag bpay_biller_code         account currency  \
# 0  authorized                1.0              NaN  ACC-1598451071      AUD
# 1  authorized                0.0              NaN  ACC-1598451071      AUD
# 2  authorized                1.0              NaN  ACC-1222300524      AUD
# 3  authorized                1.0              NaN  ACC-1037050564      AUD
# 4  authorized                1.0              NaN  ACC-1598451071      AUD
#
#         long_lat txn_description                           merchant_id  \
# 0  153.41 -27.95             POS  81c48296-73be-44a7-befa-d053f48ce7cd
# 1  153.41 -27.95       SALES-POS  830a451c-316e-4a6a-bf25-e37caedca49e
# 2  151.23 -33.94             POS  835c231d-8cdf-4e96-859d-e9d571760cf0
# 3  153.10 -27.66       SALES-POS  48514682-c78a-4a88-b0da-2d6302e64673
# 4  153.41 -27.95       SALES-POS  b4e02c10-0852-4273-b8fd-7b3395e32eb0
#
#    merchant_code first_name  ...  age merchant_suburb merchant_state  \
# ...

# %% [markdown]
# # ACCESS

# %%
df
# Out:
#            status  card_present_flag bpay_biller_code         account  \
# 0      authorized                1.0              NaN  ACC-1598451071
# 1      authorized                0.0              NaN  ACC-1598451071
# 2      authorized                1.0              NaN  ACC-1222300524
# 3      authorized                1.0              NaN  ACC-1037050564
# 4      authorized                1.0              NaN  ACC-1598451071
# ...           ...                ...              ...             ...
# 12038  authorized                0.0              NaN  ACC-3021093232
# 12039  authorized                1.0              NaN  ACC-1608363396
# 12040  authorized                1.0              NaN  ACC-3827517394
# 12041  authorized                1.0              NaN  ACC-2920611728
# 12042  authorized                1.0              NaN  ACC-1443681913
#
#       currency       long_lat txn_description  \
# 0          AUD  153.41 -27.95             POS
# ...

# %%
df.info() #extracting the concise summary of the data 

#to check for nullvalues; print(ANZ.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12043 entries, 0 to 12042
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   status             12043 non-null  object
#  1   card_present_flag  7717 non-null   float64
#  2   bpay_biller_code   885 non-null    object
#  3   account            12043 non-null  object
#  4   currency           12043 non-null  object
#  5   long_lat           12043 non-null  object
#  6   txn_description    12043 non-null  object
#  7   merchant_id        7717 non-null   object
#  8   merchant_code      883 non-null    float64
#  9   first_name         12043 non-null  object
#  10  balance            12043 non-null  float64
#  11  date               12043 non-null  object
#  12  gender             12043 non-null  object
#  13  age                12043 non-null  int64
#  14  merchant_suburb    7717 non-null   object
#  15  merchant_state     7717 non-null   object
# ...

# %%
df.nunique() #this is to find the number of unique values in this column
# Out:
# status                   2
# card_present_flag        2
# bpay_biller_code         3
# account                100
# currency                 1
# long_lat               100
# txn_description          6
# merchant_id           5725
# merchant_code            1
# first_name              80
# balance              12006
# date                    91
# gender                   2
# age                     33
# merchant_suburb       1609
# merchant_state           8
# extraction            9442
# amount                4457
# transaction_id       12043
# country                  1
# customer_id            100
# merchant_long_lat     2703
# movement                 2
# dtype: int64

# %%
#accessing the data type of each column
df.dtypes
# Out:
# status                object
# card_present_flag    float64
# bpay_biller_code      object
# account               object
# currency              object
# long_lat              object
# txn_description       object
# merchant_id           object
# merchant_code        float64
# first_name            object
# balance              float64
# date                  object
# gender                object
# age                    int64
# merchant_suburb       object
# merchant_state        object
# extraction            object
# amount               float64
# transaction_id        object
# country               object
# customer_id           object
# merchant_long_lat     object
# movement              object
# dtype: object

# %%
df.shape
# Out:
# (12043, 23)

# %%
df.describe()
# Out:
#        card_present_flag  merchant_code        balance           age  \
# count        7717.000000          883.0   12043.000000  12043.000000
# mean            0.802644            0.0   14704.195553     30.582330
# std             0.398029            0.0   31503.722652     10.046343
# min             0.000000            0.0       0.240000     18.000000
# 25%             1.000000            0.0    3158.585000     22.000000
# 50%             1.000000            0.0    6432.010000     28.000000
# 75%             1.000000            0.0   12465.945000     38.000000
# max             1.000000            0.0  267128.520000     78.000000
#
#              amount
# count  12043.000000
# mean     187.933588
# std      592.599934
# min        0.100000
# 25%       16.000000
# 50%       29.000000
# 75%       53.655000
# max     8835.980000

# %% [markdown]
# * Notes
# * Fix date data type change data data type from oject to date data type
# * Encode Gender data to ones and zeros. [one hot encoding]

# %% [markdown]
# # CLEAN

# %% [markdown]
# #### DEFINE

# %% [markdown]
# * change date data type to datetime data type
# * check if its possible to create a dictionary that assigns the customer id column to the first name column
# * use fewer and more important columns [feature selection]
# * Replace missing values in the merchant_suburb column

# %% [markdown]
# #### CODE

# %%
df_clean = pd.read_csv('ANZ.csv', usecols=[0,6,9,10,11,12,13,14,17,20])
#Feature selection, selecting important features

# %%
df_clean.head()
# Out:
#        status txn_description first_name  balance      date gender  age  \
# 0  authorized             POS      Diana    35.39  8/1/2018      F   26
# 1  authorized       SALES-POS      Diana    21.20  8/1/2018      F   26
# 2  authorized             POS    Michael     5.71  8/1/2018      M   38
# 3  authorized       SALES-POS     Rhonda  2117.22  8/1/2018      F   40
# 4  authorized       SALES-POS      Diana    17.95  8/1/2018      F   26
#
#   merchant_suburb  amount     customer_id
# 0         Ashmore   16.25  CUS-2487424745
# 1          Sydney   14.19  CUS-2487424745
# 2          Sydney    6.42  CUS-2142601169
# 3         Buderim   40.90  CUS-1614226872
# 4   Mermaid Beach    3.25  CUS-2487424745

# %% [markdown]
# * contains one column with missing values

# %%
#checking for duplicated rows/observations
sum(df_clean.duplicated())
# Out:
# 0

# %%
df_clean = df.copy()

# %%
#dropping duplicates
df_clean.drop_duplicates(inplace=True)

# %%
sum(df_clean.duplicated())
# Out:
# 0

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12043 entries, 0 to 12042
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   status           12043 non-null  object
#  1   txn_description  12043 non-null  object
#  2   first_name       12043 non-null  object
#  3   balance          12043 non-null  float64
#  4   date             12043 non-null  object
#  5   gender           12043 non-null  object
#  6   age              12043 non-null  int64
#  7   merchant_suburb  7717 non-null   object
#  8   amount           12043 non-null  float64
#  9   customer_id      12043 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 941.0+ KB

# %% [markdown]
# * fixing missing value
# mean = df_clean['merchant_suburb'].mean()
# df_clean['merchant_suburb'].fillna(mean)

# %%
# fixing incoorect data type (date)
df_clean['date'] = pd.to_datetime(df_clean['date'])

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12043 entries, 0 to 12042
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   status           12043 non-null  object
#  1   txn_description  12043 non-null  object
#  2   first_name       12043 non-null  object
#  3   balance          12043 non-null  float64
#  4   date             12043 non-null  datetime64[ns]
#  5   gender           12043 non-null  object
#  6   age              12043 non-null  int64
#  7   merchant_suburb  7717 non-null   object
#  8   amount           12043 non-null  float64
#  9   customer_id      12043 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(6)
# memory usage: 941.0+ KB

# %% [markdown]
# * for example, if i need to save as a separate file
# df.to_csv("anz_edited.csv", index=False)

# %%
# view data plot with the hist() function in pandas

# %matplotlib inline
df_clean.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001EA05AE2188>,
# ...
#       dtype=object)

# %%
df_clean.tail()
# Out:
#            status txn_description first_name       date gender  age  \
# 12038  authorized             POS    Melissa 2018-10-31      F   30
# 12039  authorized       SALES-POS     Robert 2018-10-31      M   20
# 12040  authorized             POS      Craig 2018-10-31      M   28
# 12041  authorized       SALES-POS      Tyler 2018-10-31      M   69
# 12042  authorized       SALES-POS       Ryan 2018-10-31      M   31
#
#       merchant_suburb  amount     customer_id
# 12038        Ringwood    9.79    CUS-55310383
# 12039          Casula   63.87  CUS-2688605418
# 12040      Kings Park   43.96  CUS-2663907001
# 12041        Oakleigh   30.77  CUS-1388323263
# 12042          Mascot   22.36  CUS-3129499595

# %% [markdown]
# e.g # total sales during most recent 3 month period
# last_three_months = df[df['week']>= '2017-12-01']
# last_three_months.iloc[:, 1:].sum() # exclude sum of week column

# %%
 df_clean.gender= pd.get_dummies(df_clean.gender) #encoding the gender feature into ones and zeros

# %%
df_clean.head() #females have become 1's and males 0's.
# Out:
#        status txn_description first_name  balance       date  gender  age  \
# 0  authorized             POS      Diana    35.39 2018-08-01       1   26
# 1  authorized       SALES-POS      Diana    21.20 2018-08-01       1   26
# 2  authorized             POS    Michael     5.71 2018-08-01       0   38
# 3  authorized       SALES-POS     Rhonda  2117.22 2018-08-01       1   40
# 4  authorized       SALES-POS      Diana    17.95 2018-08-01       1   26
#
#   merchant_suburb  amount     customer_id
# 0         Ashmore   16.25  CUS-2487424745
# 1          Sydney   14.19  CUS-2487424745
# 2          Sydney    6.42  CUS-2142601169
# 3         Buderim   40.90  CUS-1614226872
# 4   Mermaid Beach    3.25  CUS-2487424745

# %% [markdown]
# #### Calculations
# * Calculate and Analyze the annual Salary for each customer
# * Explore the correlations between the annual salary and features such as age, gender, and other purchasing behaviour
# * Visualize correlations in a scatterplot
# * after finding correlations, build a simple regression model that uses these features above to predict annual salary
# * Build a decision tree based model to predict salaries.
# * How accurate are the models? and what would you do to accurately test their performance?

# %%
df_clean.groupby(['first_name','txn_description'])['amount'].sum()
# Out:
# first_name  txn_description
# Abigail     INTER BANK           228.00
#             PAY/SALARY         25305.41
#             PAYMENT             1917.00
#             POS                 1123.78
#             SALES-POS           1137.73
#                                  ...
# Virginia    INTER BANK          1579.00
#             PAY/SALARY         14804.27
#             PAYMENT              897.00
#             POS                 1700.88
#             SALES-POS           2875.66
# Name: amount, Length: 391, dtype: float64

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df_clean.groupby(['first_name',df_clean['txn_description']== 'PAY/SALARY'])['amount'].sum()
# Out:
# first_name  txn_description
# Abigail     False               4406.51
#             True               25305.41
# Alexander   False               5801.12
#             True               21897.06
# Amy         False               4980.98
#                                  ...
# Tonya       True               19881.05
# Tyler       False               9975.41
#             True               31927.72
# Virginia    False               7052.54
#             True               14804.27
# Name: amount, Length: 160, dtype: float64

# %%
pd.options.display.max_colwidth = 100

# %%
df_clean.groupby(['first_name',df_clean['txn_description']== 'PAY/SALARY'])['amount'].sum()
# Out:
# first_name  txn_description
# Abigail     False               4406.51
#             True               25305.41
# Alexander   False               5801.12
#             True               21897.06
# Amy         False               4980.98
#                                  ...
# Tonya       True               19881.05
# Tyler       False               9975.41
#             True               31927.72
# Virginia    False               7052.54
#             True               14804.27
# Name: amount, Length: 160, dtype: float64

# %%
pd.options.display.max_rows = 4000
#remove the ellipses in the display

# %%
df_clean[df_clean['txn_description']=='PAY/SALARY'].groupby(['customer_id','first_name'])['amount'].sum()
#removing the T/F format and grouping based on the pay/salary in the txn description.
# Out:
# customer_id     first_name
# CUS-1005756958  Stephanie      12616.11
# CUS-1117979751  Lucas          25050.55
# CUS-1140341822  Dustin         11499.06
# CUS-1147642491  Robin          22248.07
# CUS-1196156254  Jessica        27326.11
# CUS-1220154422  Ashley         15976.52
# CUS-1233833708  Michael         7155.96
# CUS-1271030853  Michele        16214.10
# CUS-127297539   Virginia       14804.27
# CUS-134193016   Rachael        14165.76
# CUS-134833760   Billy          26500.46
# CUS-1388323263  Tyler          14603.68
# CUS-1433879684  Jeffrey         9856.56
# CUS-1462656821  Isaiah         27327.65
# CUS-1478398256  Alexander      21897.06
# CUS-1499065773  Sarah          14822.70
# CUS-1604596597  Barry          15000.00
# CUS-1609060617  Michael        17128.44
# CUS-1614226872  Rhonda         11597.17
# CUS-1617121891  Daniel         23301.39
# CUS-164374203   Susan          19536.86
# CUS-1646183815  Andrew          9389.04
# CUS-1646621553  Antonio        15384.74
# ...

# %%
annual_salary = df_clean[df_clean['txn_description']=='PAY/SALARY'].groupby(['customer_id','first_name'])['amount'].sum()

# %%
annual_salary.head(5)
# Out:
# customer_id     first_name
# CUS-1005756958  Stephanie     12616.11
# CUS-1117979751  Lucas         25050.55
# CUS-1140341822  Dustin        11499.06
# CUS-1147642491  Robin         22248.07
# CUS-1196156254  Jessica       27326.11
# Name: amount, dtype: float64

# %%
annual_salary['annual'] = annual_salary[2] *4

# %%
annual_salary.nunique()
# Out:
# 101

# %%
df_clean.dtypes
# Out:
# status                     object
# txn_description            object
# first_name                 object
# balance                   float64
# date               datetime64[ns]
# gender                      uint8
# age                         int64
# merchant_suburb            object
# amount                    float64
# customer_id                object
# dtype: object

# %%
annual_salary['annual'] = annual_salary[0] *4
#this code adds another row to multiply the first row's values by 4

# %%
annual_salary[0]
# Out:
# 12616.109999999999

# %%
df_cleaned = pd.read_csv('quarterly.csv')

# %%
df_cleaned.head()
# Out:
#       customer_id first_name  quarterly
# 0  CUS-1005756958  Stephanie   12616.11
# 1  CUS-1117979751      Lucas   25050.55
# 2  CUS-1140341822     Dustin   11499.06
# 3  CUS-1147642491      Robin   22248.07
# 4  CUS-1196156254    Jessica   27326.11

# %%
df_cleaned['annual']= df_cleaned['quarterly']*4

# %%
df_cleaned.head()
# Out:
#        customer_id   first_name  quarterly     annual
# 0   CUS-1005756958    Stephanie   12616.11   50464.44
# 1   CUS-1117979751        Lucas   25050.55  100202.20
# 2   CUS-1140341822       Dustin   11499.06   45996.24
# 3   CUS-1147642491        Robin   22248.07   88992.28
# 4   CUS-1196156254      Jessica   27326.11  109304.44
# 5   CUS-1220154422       Ashley   15976.52   63906.08
# 6   CUS-1233833708      Michael    7155.96   28623.84
# 7   CUS-1271030853      Michele   16214.10   64856.40
# 8    CUS-127297539     Virginia   14804.27   59217.08
# 9    CUS-134193016      Rachael   14165.76   56663.04
# 10   CUS-134833760        Billy   26500.46  106001.84
# 11  CUS-1388323263        Tyler   14603.68   58414.72
# 12  CUS-1433879684      Jeffrey    9856.56   39426.24
# 13  CUS-1462656821       Isaiah   27327.65  109310.60
# 14  CUS-1478398256    Alexander   21897.06   87588.24
# 15  CUS-1499065773        Sarah   14822.70   59290.80
# ...

# %%
#correlations between annual salary and purchasing behaviour e.g. age, gender etc.
df_clean
